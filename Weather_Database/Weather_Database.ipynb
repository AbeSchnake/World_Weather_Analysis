# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from Config import api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 760

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# %%
import time

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | moses lake
# Processing Record 4 of Set 1 | pinhao
# Processing Record 5 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 1 | puerto ayora
# Processing Record 7 of Set 1 | pichayevo
# Processing Record 8 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 1 | altay
# Processing Record 10 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 1 | butaritari
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | samarai
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | camacha
# Processing Record 16 of Set 1 | puerto escondido
# Processing Record 17 of Set 1 | fairbanks
# Processing Record 18 of Set 1 | yellowknife
# Processing Record 19 of Set 1 | hasaki
# Processing Record 20 of Set 1 | vaini
# Processing Record 21 of Set 1 | lebu
# Processing Record 22 of Set 1 | guymon
# Processing Record 23 of Set 1 | klaksvik
# Processing Record 24 of Set 1 | xining
# Processing Record 25 of Set 1 | baglung
# Processing Record 26 of Set 1 | mataura
# Processing Record 27 of Set 1 | zaysan
# Processing Record 28 of Set 1 | nadym
# Processing Record 29 of Set 1 | diamantino
# Processing Record 30 of Set 1 | kapaa
# Processing Record 31 of Set 1 | barrow
# Processing Record 32 of Set 1 | ilulissat
# Processing Record 33 of Set 1 | tasiilaq
# Processing Record 34 of Set 1 | severo-kurilsk
# Processing Record 35 of Set 1 | flinders
# Processing Record 36 of Set 1 | moose factory
# Processing Record 37 of Set 1 | lompoc
# Processing Record 38 of Set 1 | westport
# Processing Record 39 of Set 1 | hilo
# Processing Record 40 of Set 1 | mayo
# Processing Record 41 of Set 1 | new norfolk
# Processing Record 42 of Set 1 | hermanus
# Processing Record 43 of Set 1 | labuhan
# Processing Record 44 of Set 1 | tadine
# Processing Record 45 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 46 of Set 1 | victoria
# Processing Record 47 of Set 1 | egvekinot
# Processing Record 48 of Set 1 | atuona
# Processing Record 49 of Set 1 | hobart
# Processing Record 50 of Set 1 | sitka
# Processing Record 1 of Set 2 | sawtell
# Processing Record 2 of Set 2 | tilichiki
# Processing Record 3 of Set 2 | los llanos de aridane
# Processing Record 4 of Set 2 | buqayq
# City not found. Skipping...
# Processing Record 5 of Set 2 | lagoa
# Processing Record 6 of Set 2 | santiago del estero
# Processing Record 7 of Set 2 | qaanaaq
# Processing Record 8 of Set 2 | half moon bay
# Processing Record 9 of Set 2 | arraial do cabo
# Processing Record 10 of Set 2 | port elizabeth
# Processing Record 11 of Set 2 | la baule-escoublac
# Processing Record 12 of Set 2 | beloha
# Processing Record 13 of Set 2 | bredasdorp
# Processing Record 14 of Set 2 | mocambique
# City not found. Skipping...
# Processing Record 15 of Set 2 | saldanha
# Processing Record 16 of Set 2 | ribeira grande
# Processing Record 17 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 18 of Set 2 | provideniya
# Processing Record 19 of Set 2 | port alfred
# Processing Record 20 of Set 2 | kantunilkin
# Processing Record 21 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 22 of Set 2 | una
# Processing Record 23 of Set 2 | cidreira
# Processing Record 24 of Set 2 | santo antonio do ica
# Processing Record 25 of Set 2 | hithadhoo
# Processing Record 26 of Set 2 | nouakchott
# Processing Record 27 of Set 2 | bluff
# Processing Record 28 of Set 2 | dikson
# Processing Record 29 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 30 of Set 2 | carnaiba
# Processing Record 31 of Set 2 | sovetskaya gavan
# Processing Record 32 of Set 2 | vardo
# Processing Record 33 of Set 2 | sakakah
# Processing Record 34 of Set 2 | roald
# Processing Record 35 of Set 2 | khani
# Processing Record 36 of Set 2 | saint george
# Processing Record 37 of Set 2 | tres arroyos
# Processing Record 38 of Set 2 | cabo san lucas
# Processing Record 39 of Set 2 | sao filipe
# Processing Record 40 of Set 2 | tuktoyaktuk
# Processing Record 41 of Set 2 | sistranda
# Processing Record 42 of Set 2 | bethel
# Processing Record 43 of Set 2 | buala
# Processing Record 44 of Set 2 | ratnagiri
# Processing Record 45 of Set 2 | aklavik
# Processing Record 46 of Set 2 | vilhena
# Processing Record 47 of Set 2 | mazyr
# Processing Record 48 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 2 | airai
# Processing Record 50 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 1 of Set 3 | praia
# Processing Record 2 of Set 3 | maningrida
# Processing Record 3 of Set 3 | kahului
# Processing Record 4 of Set 3 | okhotsk
# Processing Record 5 of Set 3 | jumla
# Processing Record 6 of Set 3 | suicheng
# Processing Record 7 of Set 3 | thompson
# Processing Record 8 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 3 | longyearbyen
# Processing Record 10 of Set 3 | bongandanga
# Processing Record 11 of Set 3 | kloulklubed
# Processing Record 12 of Set 3 | nikolskoye
# Processing Record 13 of Set 3 | inhambane
# Processing Record 14 of Set 3 | muskegon
# Processing Record 15 of Set 3 | nueve de julio
# Processing Record 16 of Set 3 | nurota
# Processing Record 17 of Set 3 | umm lajj
# Processing Record 18 of Set 3 | mitsamiouli
# Processing Record 19 of Set 3 | laurel
# Processing Record 20 of Set 3 | jamestown
# Processing Record 21 of Set 3 | bengkulu
# Processing Record 22 of Set 3 | mahebourg
# Processing Record 23 of Set 3 | cheuskiny
# City not found. Skipping...
# Processing Record 24 of Set 3 | zlobin
# Processing Record 25 of Set 3 | oranjestad
# Processing Record 26 of Set 3 | cherskiy
# Processing Record 27 of Set 3 | talnakh
# Processing Record 28 of Set 3 | ajra
# Processing Record 29 of Set 3 | pangkalanbuun
# Processing Record 30 of Set 3 | midland
# Processing Record 31 of Set 3 | rio grande
# Processing Record 32 of Set 3 | mar del plata
# Processing Record 33 of Set 3 | aras
# Processing Record 34 of Set 3 | edson
# Processing Record 35 of Set 3 | qui nhon
# Processing Record 36 of Set 3 | bagli
# Processing Record 37 of Set 3 | kaka
# Processing Record 38 of Set 3 | port hardy
# Processing Record 39 of Set 3 | busselton
# Processing Record 40 of Set 3 | brae
# Processing Record 41 of Set 3 | saint-michel-des-saints
# Processing Record 42 of Set 3 | wick
# Processing Record 43 of Set 3 | salamiyah
# Processing Record 44 of Set 3 | garissa
# Processing Record 45 of Set 3 | pangnirtung
# Processing Record 46 of Set 3 | acarau
# Processing Record 47 of Set 3 | bambous virieux
# Processing Record 48 of Set 3 | piltene
# Processing Record 49 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 50 of Set 3 | phnum penh
# City not found. Skipping...
# Processing Record 1 of Set 4 | san patricio
# Processing Record 2 of Set 4 | guerrero negro
# Processing Record 3 of Set 4 | souillac
# Processing Record 4 of Set 4 | avera
# Processing Record 5 of Set 4 | san luis
# Processing Record 6 of Set 4 | szczytno
# Processing Record 7 of Set 4 | tiznit
# Processing Record 8 of Set 4 | salalah
# Processing Record 9 of Set 4 | yulara
# Processing Record 10 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 11 of Set 4 | tiksi
# Processing Record 12 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 13 of Set 4 | ponta do sol
# Processing Record 14 of Set 4 | nowe miasto lubawskie
# Processing Record 15 of Set 4 | luderitz
# Processing Record 16 of Set 4 | zhanatas
# City not found. Skipping...
# Processing Record 17 of Set 4 | yar-sale
# Processing Record 18 of Set 4 | buraydah
# Processing Record 19 of Set 4 | kunya
# Processing Record 20 of Set 4 | broome
# Processing Record 21 of Set 4 | henties bay
# Processing Record 22 of Set 4 | padang
# Processing Record 23 of Set 4 | urdzhar
# City not found. Skipping...
# Processing Record 24 of Set 4 | keetmanshoop
# Processing Record 25 of Set 4 | fortuna foothills
# Processing Record 26 of Set 4 | road town
# Processing Record 27 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 28 of Set 4 | cape town
# Processing Record 29 of Set 4 | pallipattu
# Processing Record 30 of Set 4 | mount gambier
# Processing Record 31 of Set 4 | longonjo
# Processing Record 32 of Set 4 | dunedin
# Processing Record 33 of Set 4 | zharkent
# Processing Record 34 of Set 4 | gillette
# Processing Record 35 of Set 4 | kuah
# Processing Record 36 of Set 4 | mirante do paranapanema
# Processing Record 37 of Set 4 | mudhol
# Processing Record 38 of Set 4 | la ronge
# Processing Record 39 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 40 of Set 4 | utiroa
# City not found. Skipping...
# Processing Record 41 of Set 4 | vorozhba
# Processing Record 42 of Set 4 | yarim
# Processing Record 43 of Set 4 | qasigiannguit
# Processing Record 44 of Set 4 | margate
# Processing Record 45 of Set 4 | kavieng
# Processing Record 46 of Set 4 | xam nua
# Processing Record 47 of Set 4 | camargo
# Processing Record 48 of Set 4 | ajdabiya
# Processing Record 49 of Set 4 | bulaevo
# Processing Record 50 of Set 4 | leningradskiy
# Processing Record 1 of Set 5 | sayyan
# Processing Record 2 of Set 5 | colares
# Processing Record 3 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 5 | georgetown
# Processing Record 5 of Set 5 | atar
# Processing Record 6 of Set 5 | bogorodskoye
# Processing Record 7 of Set 5 | tazovskiy
# Processing Record 8 of Set 5 | kodiak
# Processing Record 9 of Set 5 | redlands
# Processing Record 10 of Set 5 | kirakira
# Processing Record 11 of Set 5 | geraldton
# Processing Record 12 of Set 5 | kaitangata
# Processing Record 13 of Set 5 | saint-philippe
# Processing Record 14 of Set 5 | cap-aux-meules
# Processing Record 15 of Set 5 | pevek
# Processing Record 16 of Set 5 | nantucket
# Processing Record 17 of Set 5 | itarema
# Processing Record 18 of Set 5 | nouadhibou
# Processing Record 19 of Set 5 | vila franca do campo
# Processing Record 20 of Set 5 | khatanga
# Processing Record 21 of Set 5 | kang
# Processing Record 22 of Set 5 | tahta
# Processing Record 23 of Set 5 | maniwaki
# Processing Record 24 of Set 5 | kurilsk
# Processing Record 25 of Set 5 | saravan
# Processing Record 26 of Set 5 | meulaboh
# Processing Record 27 of Set 5 | tezu
# Processing Record 28 of Set 5 | viedma
# Processing Record 29 of Set 5 | chuy
# Processing Record 30 of Set 5 | shimoda
# Processing Record 31 of Set 5 | kapit
# Processing Record 32 of Set 5 | ixtapa
# Processing Record 33 of Set 5 | san policarpo
# Processing Record 34 of Set 5 | ostrovnoy
# Processing Record 35 of Set 5 | carutapera
# Processing Record 36 of Set 5 | asfi
# Processing Record 37 of Set 5 | kota bahru
# Processing Record 38 of Set 5 | rafaela
# Processing Record 39 of Set 5 | chokurdakh
# Processing Record 40 of Set 5 | vallenar
# Processing Record 41 of Set 5 | sakyla
# Processing Record 42 of Set 5 | cayenne
# Processing Record 43 of Set 5 | kultuk
# Processing Record 44 of Set 5 | east london
# Processing Record 45 of Set 5 | constitucion
# Processing Record 46 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 5 | berbera
# Processing Record 48 of Set 5 | tigil
# Processing Record 49 of Set 5 | nsanje
# Processing Record 50 of Set 5 | praya
# Processing Record 1 of Set 6 | kruisfontein
# Processing Record 2 of Set 6 | biltine
# Processing Record 3 of Set 6 | talara
# Processing Record 4 of Set 6 | inuvik
# Processing Record 5 of Set 6 | castro
# Processing Record 6 of Set 6 | laguna
# Processing Record 7 of Set 6 | thio
# Processing Record 8 of Set 6 | moron
# Processing Record 9 of Set 6 | lorengau
# Processing Record 10 of Set 6 | sur
# Processing Record 11 of Set 6 | tuatapere
# Processing Record 12 of Set 6 | ust-kuyga
# Processing Record 13 of Set 6 | luwuk
# Processing Record 14 of Set 6 | faanui
# Processing Record 15 of Set 6 | sao jose da coroa grande
# Processing Record 16 of Set 6 | esna
# Processing Record 17 of Set 6 | pirenopolis
# Processing Record 18 of Set 6 | inirida
# Processing Record 19 of Set 6 | upernavik
# Processing Record 20 of Set 6 | mangan
# Processing Record 21 of Set 6 | grindavik
# Processing Record 22 of Set 6 | carnarvon
# Processing Record 23 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 24 of Set 6 | kieta
# Processing Record 25 of Set 6 | mentok
# City not found. Skipping...
# Processing Record 26 of Set 6 | tubruq
# City not found. Skipping...
# Processing Record 27 of Set 6 | abu samrah
# Processing Record 28 of Set 6 | maumere
# Processing Record 29 of Set 6 | guanica
# Processing Record 30 of Set 6 | sumbe
# Processing Record 31 of Set 6 | anchorage
# Processing Record 32 of Set 6 | soroti
# Processing Record 33 of Set 6 | lensk
# Processing Record 34 of Set 6 | tvoroyri
# Processing Record 35 of Set 6 | suzu
# City not found. Skipping...
# Processing Record 36 of Set 6 | vaitape
# Processing Record 37 of Set 6 | alofi
# Processing Record 38 of Set 6 | arona
# Processing Record 39 of Set 6 | richards bay
# Processing Record 40 of Set 6 | monterey
# Processing Record 41 of Set 6 | maceio
# Processing Record 42 of Set 6 | karratha
# Processing Record 43 of Set 6 | tessalit
# Processing Record 44 of Set 6 | aquiraz
# Processing Record 45 of Set 6 | pierre
# Processing Record 46 of Set 6 | okakarara
# Processing Record 47 of Set 6 | ostersund
# Processing Record 48 of Set 6 | bilibino
# Processing Record 49 of Set 6 | vestmannaeyjar
# Processing Record 50 of Set 6 | ola
# Processing Record 1 of Set 7 | butwal
# Processing Record 2 of Set 7 | poronaysk
# Processing Record 3 of Set 7 | arlit
# Processing Record 4 of Set 7 | quballat
# Processing Record 5 of Set 7 | avarua
# Processing Record 6 of Set 7 | basco
# Processing Record 7 of Set 7 | lixourion
# Processing Record 8 of Set 7 | bac lieu
# Processing Record 9 of Set 7 | balimo
# City not found. Skipping...
# Processing Record 10 of Set 7 | hami
# Processing Record 11 of Set 7 | limulunga
# Processing Record 12 of Set 7 | iqaluit
# Processing Record 13 of Set 7 | ginir
# Processing Record 14 of Set 7 | bud
# Processing Record 15 of Set 7 | matara
# Processing Record 16 of Set 7 | tucupita
# Processing Record 17 of Set 7 | charters towers
# Processing Record 18 of Set 7 | todos santos
# Processing Record 19 of Set 7 | norman wells
# Processing Record 20 of Set 7 | caravelas
# Processing Record 21 of Set 7 | makakilo city
# Processing Record 22 of Set 7 | san quintin
# Processing Record 23 of Set 7 | manaquiri
# Processing Record 24 of Set 7 | fortuna
# Processing Record 25 of Set 7 | virginia beach
# Processing Record 26 of Set 7 | nome
# Processing Record 27 of Set 7 | narsaq
# Processing Record 28 of Set 7 | velka bystrice
# Processing Record 29 of Set 7 | soldotna
# Processing Record 30 of Set 7 | coxim
# Processing Record 31 of Set 7 | pakxe
# Processing Record 32 of Set 7 | gunjur
# Processing Record 33 of Set 7 | comodoro rivadavia
# Processing Record 34 of Set 7 | kudahuvadhoo
# Processing Record 35 of Set 7 | san jose de guanipa
# Processing Record 36 of Set 7 | paamiut
# Processing Record 37 of Set 7 | touros
# Processing Record 38 of Set 7 | port blair
# Processing Record 39 of Set 7 | kavaratti
# Processing Record 40 of Set 7 | kopong
# Processing Record 41 of Set 7 | kyra
# Processing Record 42 of Set 7 | kasongo-lunda
# Processing Record 43 of Set 7 | pacific grove
# Processing Record 44 of Set 7 | magugu
# Processing Record 45 of Set 7 | guaymas
# Processing Record 46 of Set 7 | pisco
# Processing Record 47 of Set 7 | uchiza
# Processing Record 48 of Set 7 | tual
# Processing Record 49 of Set 7 | alice springs
# Processing Record 50 of Set 7 | nador
# Processing Record 1 of Set 8 | caluquembe
# Processing Record 2 of Set 8 | tura
# Processing Record 3 of Set 8 | palampur
# Processing Record 4 of Set 8 | vuktyl
# Processing Record 5 of Set 8 | lambari
# Processing Record 6 of Set 8 | birjand
# Processing Record 7 of Set 8 | camopi
# Processing Record 8 of Set 8 | nawashahr
# Processing Record 9 of Set 8 | sao felix do xingu
# Processing Record 10 of Set 8 | cossato
# Processing Record 11 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 8 | awjilah
# Processing Record 13 of Set 8 | puertollano
# Processing Record 14 of Set 8 | nikki
# Processing Record 15 of Set 8 | ardistan
# City not found. Skipping...
# Processing Record 16 of Set 8 | inderborskiy
# City not found. Skipping...
# Processing Record 17 of Set 8 | manjacaze
# Processing Record 18 of Set 8 | cristalina
# Processing Record 19 of Set 8 | nortelandia
# Processing Record 20 of Set 8 | sao sebastiao
# Processing Record 21 of Set 8 | oriximina
# Processing Record 22 of Set 8 | bahar
# Processing Record 23 of Set 8 | saryshagan
# City not found. Skipping...
# Processing Record 24 of Set 8 | karpathos
# Processing Record 25 of Set 8 | birao
# Processing Record 26 of Set 8 | saskylakh
# Processing Record 27 of Set 8 | lavrentiya
# Processing Record 28 of Set 8 | xichang
# Processing Record 29 of Set 8 | nanortalik
# Processing Record 30 of Set 8 | coihaique
# Processing Record 31 of Set 8 | ahipara
# Processing Record 32 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 33 of Set 8 | mullaitivu
# City not found. Skipping...
# Processing Record 34 of Set 8 | andover
# Processing Record 35 of Set 8 | bagotville
# Processing Record 36 of Set 8 | vieux-habitants
# Processing Record 37 of Set 8 | harper
# Processing Record 38 of Set 8 | torbay
# Processing Record 39 of Set 8 | verkhnevilyuysk
# Processing Record 40 of Set 8 | beringovskiy
# Processing Record 41 of Set 8 | hobyo
# Processing Record 42 of Set 8 | ribas do rio pardo
# Processing Record 43 of Set 8 | zhezkazgan
# Processing Record 44 of Set 8 | baijiantan
# Processing Record 45 of Set 8 | codrington
# Processing Record 46 of Set 8 | wamba
# Processing Record 47 of Set 8 | oxford
# Processing Record 48 of Set 8 | usinsk
# Processing Record 49 of Set 8 | puerto el triunfo
# Processing Record 50 of Set 8 | thinadhoo
# Processing Record 1 of Set 9 | grand junction
# Processing Record 2 of Set 9 | mega
# Processing Record 3 of Set 9 | mirabad
# Processing Record 4 of Set 9 | manacapuru
# Processing Record 5 of Set 9 | muroto
# Processing Record 6 of Set 9 | olga
# Processing Record 7 of Set 9 | dzhebariki-khaya
# Processing Record 8 of Set 9 | laiagam
# City not found. Skipping...
# Processing Record 9 of Set 9 | pinehurst
# Processing Record 10 of Set 9 | izumo
# Processing Record 11 of Set 9 | guiratinga
# Processing Record 12 of Set 9 | nohfelden
# Processing Record 13 of Set 9 | port lincoln
# Processing Record 14 of Set 9 | sorong
# Processing Record 15 of Set 9 | camocim
# Processing Record 16 of Set 9 | namibe
# Processing Record 17 of Set 9 | bousso
# Processing Record 18 of Set 9 | hirna
# Processing Record 19 of Set 9 | maragogi
# Processing Record 20 of Set 9 | quatre cocos
# Processing Record 21 of Set 9 | saint-francois
# Processing Record 22 of Set 9 | pokrovskoye
# Processing Record 23 of Set 9 | kenai
# Processing Record 24 of Set 9 | kofarnihon
# City not found. Skipping...
# Processing Record 25 of Set 9 | monte escobedo
# Processing Record 26 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 27 of Set 9 | horta
# Processing Record 28 of Set 9 | hudiksvall
# Processing Record 29 of Set 9 | boone
# Processing Record 30 of Set 9 | ningan
# City not found. Skipping...
# Processing Record 31 of Set 9 | cervo
# Processing Record 32 of Set 9 | traverse city
# Processing Record 33 of Set 9 | skagastrond
# City not found. Skipping...
# Processing Record 34 of Set 9 | vilyuysk
# Processing Record 35 of Set 9 | langenburg
# Processing Record 36 of Set 9 | najran
# Processing Record 37 of Set 9 | acapulco
# Processing Record 38 of Set 9 | boyolangu
# Processing Record 39 of Set 9 | bathsheba
# Processing Record 40 of Set 9 | bubaque
# Processing Record 41 of Set 9 | tornio
# Processing Record 42 of Set 9 | te anau
# Processing Record 43 of Set 9 | mogadishu
# Processing Record 44 of Set 9 | rocha
# Processing Record 45 of Set 9 | opuwo
# Processing Record 46 of Set 9 | crab hill
# City not found. Skipping...
# Processing Record 47 of Set 9 | emerald
# Processing Record 48 of Set 9 | hirara
# Processing Record 49 of Set 9 | senanga
# Processing Record 50 of Set 9 | reconquista
# Processing Record 1 of Set 10 | sabha
# Processing Record 2 of Set 10 | ouro preto do oeste
# Processing Record 3 of Set 10 | celestun
# Processing Record 4 of Set 10 | valday
# Processing Record 5 of Set 10 | zaidpur
# Processing Record 6 of Set 10 | mbumi
# Processing Record 7 of Set 10 | karakendzha
# City not found. Skipping...
# Processing Record 8 of Set 10 | pangody
# Processing Record 9 of Set 10 | bridlington
# Processing Record 10 of Set 10 | barcelos
# Processing Record 11 of Set 10 | jinchang
# Processing Record 12 of Set 10 | kiruna
# Processing Record 13 of Set 10 | harnosand
# Processing Record 14 of Set 10 | saint anthony
# Processing Record 15 of Set 10 | luwingu
# Processing Record 16 of Set 10 | zabid
# Processing Record 17 of Set 10 | preobrazheniye
# Processing Record 18 of Set 10 | kankon
# Processing Record 19 of Set 10 | hervey bay
# Processing Record 20 of Set 10 | zhuhai
# Processing Record 21 of Set 10 | clyde river
# Processing Record 22 of Set 10 | rujiena
# Processing Record 23 of Set 10 | jabiru
# City not found. Skipping...
# Processing Record 24 of Set 10 | rio tercero
# Processing Record 25 of Set 10 | dingle
# Processing Record 26 of Set 10 | pochutla
# Processing Record 27 of Set 10 | ulu tiram
# Processing Record 28 of Set 10 | venado tuerto
# Processing Record 29 of Set 10 | sri aman
# Processing Record 30 of Set 10 | chiang klang
# Processing Record 31 of Set 10 | taurage
# Processing Record 32 of Set 10 | vao
# Processing Record 33 of Set 10 | thunder bay
# Processing Record 34 of Set 10 | jiexiu
# Processing Record 35 of Set 10 | tagusao
# Processing Record 36 of Set 10 | krasnoselkup
# Processing Record 37 of Set 10 | huadian
# Processing Record 38 of Set 10 | tiarei
# Processing Record 39 of Set 10 | rosetta
# Processing Record 40 of Set 10 | tharrawaddy
# City not found. Skipping...
# Processing Record 41 of Set 10 | berlevag
# Processing Record 42 of Set 10 | sterling
# Processing Record 43 of Set 10 | bamiantong
# Processing Record 44 of Set 10 | esperance
# Processing Record 45 of Set 10 | marawi
# Processing Record 46 of Set 10 | sarand
# Processing Record 47 of Set 10 | saint-augustin
# Processing Record 48 of Set 10 | katsuura
# Processing Record 49 of Set 10 | capao da canoa
# Processing Record 50 of Set 10 | nelson bay
# Processing Record 1 of Set 11 | ulaanbaatar
# Processing Record 2 of Set 11 | phayao
# Processing Record 3 of Set 11 | sioux lookout
# Processing Record 4 of Set 11 | murzzuschlag
# Processing Record 5 of Set 11 | baykit
# Processing Record 6 of Set 11 | bajil
# Processing Record 7 of Set 11 | amapa
# Processing Record 8 of Set 11 | ndele
# Processing Record 9 of Set 11 | kamskiye polyany
# Processing Record 10 of Set 11 | chupei
# City not found. Skipping...
# Processing Record 11 of Set 11 | onega
# Processing Record 12 of Set 11 | grand gaube
# Processing Record 13 of Set 11 | winfield
# Processing Record 14 of Set 11 | vila
# Processing Record 15 of Set 11 | martinsville
# Processing Record 16 of Set 11 | kavarskas
# Processing Record 17 of Set 11 | gorom-gorom
# Processing Record 18 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 19 of Set 11 | anadyr
# Processing Record 20 of Set 11 | mehamn
# Processing Record 21 of Set 11 | itoman
# Processing Record 22 of Set 11 | otradnoye
# Processing Record 23 of Set 11 | cosenza
# Processing Record 24 of Set 11 | baker city
# Processing Record 25 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 26 of Set 11 | nuuk
# Processing Record 27 of Set 11 | teruel
# Processing Record 28 of Set 11 | vieques
# Processing Record 29 of Set 11 | jalingo
# Processing Record 30 of Set 11 | cap malheureux
# Processing Record 31 of Set 11 | khash
# Processing Record 32 of Set 11 | mount isa
# Processing Record 33 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 11 | lar gerd
# City not found. Skipping...
# Processing Record 35 of Set 11 | oksbol
# Processing Record 36 of Set 11 | shihezi
# Processing Record 37 of Set 11 | brownwood
# Processing Record 38 of Set 11 | herat
# Processing Record 39 of Set 11 | alekseyevka
# Processing Record 40 of Set 11 | kayerkan
# Processing Record 41 of Set 11 | natal
# Processing Record 42 of Set 11 | sandovo
# Processing Record 43 of Set 11 | ponta delgada
# Processing Record 44 of Set 11 | belle fourche
# Processing Record 45 of Set 11 | nisia floresta
# Processing Record 46 of Set 11 | naarden
# Processing Record 47 of Set 11 | andenes
# Processing Record 48 of Set 11 | jinan
# Processing Record 49 of Set 11 | sahy
# Processing Record 50 of Set 11 | whitehorse
# Processing Record 1 of Set 12 | gat
# Processing Record 2 of Set 12 | redwater
# Processing Record 3 of Set 12 | bonfim
# Processing Record 4 of Set 12 | murgab
# Processing Record 5 of Set 12 | coquimbo
# Processing Record 6 of Set 12 | kongoussi
# Processing Record 7 of Set 12 | hokitika
# Processing Record 8 of Set 12 | port moresby
# Processing Record 9 of Set 12 | puerto leguizamo
# Processing Record 10 of Set 12 | turbat
# Processing Record 11 of Set 12 | guna
# Processing Record 12 of Set 12 | tori fatehpur
# Processing Record 13 of Set 12 | solsvik
# City not found. Skipping...
# Processing Record 14 of Set 12 | sabaudia
# Processing Record 15 of Set 12 | muzhi
# Processing Record 16 of Set 12 | dedovichi
# Processing Record 17 of Set 12 | dzidzantun
# Processing Record 18 of Set 12 | mabaruma
# Processing Record 19 of Set 12 | tunduru
# City not found. Skipping...
# Processing Record 20 of Set 12 | sibolga
# Processing Record 21 of Set 12 | nilanga
# Processing Record 22 of Set 12 | necochea
# Processing Record 23 of Set 12 | seda
# Processing Record 24 of Set 12 | yumen
# Processing Record 25 of Set 12 | capaci
# Processing Record 26 of Set 12 | bandarbeyla
# Processing Record 27 of Set 12 | lokosovo
# Processing Record 28 of Set 12 | segezha
# Processing Record 29 of Set 12 | nanakuli
# Processing Record 30 of Set 12 | mahadday weyne
# City not found. Skipping...
# Processing Record 31 of Set 12 | tommot
# Processing Record 32 of Set 12 | villazon
# Processing Record 33 of Set 12 | eureka
# Processing Record 34 of Set 12 | sisimiut
# Processing Record 35 of Set 12 | bonavista
# Processing Record 36 of Set 12 | claveria
# Processing Record 37 of Set 12 | hualmay
# Processing Record 38 of Set 12 | columbus
# Processing Record 39 of Set 12 | tsabong
# Processing Record 40 of Set 12 | shingu
# Processing Record 41 of Set 12 | punto fijo
# Processing Record 42 of Set 12 | trelew
# Processing Record 43 of Set 12 | maiquetia
# Processing Record 44 of Set 12 | thap than
# Processing Record 45 of Set 12 | yarega
# Processing Record 46 of Set 12 | la rioja
# Processing Record 47 of Set 12 | gushikawa
# Processing Record 48 of Set 12 | hovd
# Processing Record 49 of Set 12 | kadykchan
# City not found. Skipping...
# Processing Record 50 of Set 12 | yuli
# Processing Record 1 of Set 13 | farmington
# Processing Record 2 of Set 13 | ayios kirikos
# City not found. Skipping...
# Processing Record 3 of Set 13 | montrose
# Processing Record 4 of Set 13 | taitung
# Processing Record 5 of Set 13 | uray
# Processing Record 6 of Set 13 | kovdor
# Processing Record 7 of Set 13 | lipin bor
# Processing Record 8 of Set 13 | uruzgan
# Processing Record 9 of Set 13 | bahia honda
# Processing Record 10 of Set 13 | juneau
# Processing Record 11 of Set 13 | wanning
# Processing Record 12 of Set 13 | nishihara
# Processing Record 13 of Set 13 | maasin
# Processing Record 14 of Set 13 | urk
# Processing Record 15 of Set 13 | ankang
# Processing Record 16 of Set 13 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 13 | montepuez
# Processing Record 18 of Set 13 | ribeira brava
# Processing Record 19 of Set 13 | palu
# Processing Record 20 of Set 13 | mao
# Processing Record 21 of Set 13 | aksu
# Processing Record 22 of Set 13 | nahrin
# Processing Record 23 of Set 13 | monzon
# Processing Record 24 of Set 13 | kaeo
# Processing Record 25 of Set 13 | ulaangom
# Processing Record 26 of Set 13 | edd
# Processing Record 27 of Set 13 | tocopilla
# Processing Record 28 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 29 of Set 13 | uzhhorod
# Processing Record 30 of Set 13 | port hueneme
# Processing Record 31 of Set 13 | qurayyat
# Processing Record 32 of Set 13 | cockburn town
# Processing Record 33 of Set 13 | naze
# Processing Record 34 of Set 13 | bondo
# Processing Record 35 of Set 13 | ransang
# Processing Record 36 of Set 13 | iraucuba
# Processing Record 37 of Set 13 | paita
# Processing Record 38 of Set 13 | kingaroy
# Processing Record 39 of Set 13 | cabedelo
# Processing Record 40 of Set 13 | quimper
# Processing Record 41 of Set 13 | wenzhou
# Processing Record 42 of Set 13 | port macquarie
# Processing Record 43 of Set 13 | icara
# Processing Record 44 of Set 13 | ayagoz
# Processing Record 45 of Set 13 | muravlenko
# Processing Record 46 of Set 13 | havre-saint-pierre
# Processing Record 47 of Set 13 | pastavy
# Processing Record 48 of Set 13 | seydi
# Processing Record 49 of Set 13 | the valley
# Processing Record 50 of Set 13 | nichinan
# Processing Record 1 of Set 14 | chaa-khol
# City not found. Skipping...
# Processing Record 2 of Set 14 | hambantota
# Processing Record 3 of Set 14 | lazaro cardenas
# Processing Record 4 of Set 14 | colac
# Processing Record 5 of Set 14 | poplar bluff
# Processing Record 6 of Set 14 | biak
# Processing Record 7 of Set 14 | college
# Processing Record 8 of Set 14 | nioro
# Processing Record 9 of Set 14 | molchanovo
# Processing Record 10 of Set 14 | snezhnogorsk
# Processing Record 11 of Set 14 | zabol
# Processing Record 12 of Set 14 | poum
# Processing Record 13 of Set 14 | handwara
# City not found. Skipping...
# Processing Record 14 of Set 14 | lima
# Processing Record 15 of Set 14 | shenzhen
# Processing Record 16 of Set 14 | rosarito
# Processing Record 17 of Set 14 | prado
# Processing Record 18 of Set 14 | komsomolskiy
# Processing Record 19 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 20 of Set 14 | alyangula
# Processing Record 21 of Set 14 | hengshui
# Processing Record 22 of Set 14 | san borja
# Processing Record 23 of Set 14 | bianzhuang
# Processing Record 24 of Set 14 | batagay
# Processing Record 25 of Set 14 | pinawa
# Processing Record 26 of Set 14 | dongsheng
# Processing Record 27 of Set 14 | sinnamary
# Processing Record 28 of Set 14 | zelenoborskiy
# Processing Record 29 of Set 14 | stoyba
# City not found. Skipping...
# Processing Record 30 of Set 14 | gulbene
# Processing Record 31 of Set 14 | deputatskiy
# Processing Record 32 of Set 14 | iwanai
# Processing Record 33 of Set 14 | santa rosa
# Processing Record 34 of Set 14 | douentza
# Processing Record 35 of Set 14 | solnechnyy
# Processing Record 36 of Set 14 | kabo
# Processing Record 37 of Set 14 | el badari
# City not found. Skipping...
# Processing Record 38 of Set 14 | stokmarknes
# Processing Record 39 of Set 14 | arica
# Processing Record 40 of Set 14 | baracoa
# Processing Record 41 of Set 14 | ruatoria
# City not found. Skipping...
# Processing Record 42 of Set 14 | nemuro
# Processing Record 43 of Set 14 | motala
# Processing Record 44 of Set 14 | vanimo
# Processing Record 45 of Set 14 | sao geraldo do araguaia
# Processing Record 46 of Set 14 | edgewater
# Processing Record 47 of Set 14 | tosya
# Processing Record 48 of Set 14 | srednekolymsk
# Processing Record 49 of Set 14 | vila velha
# Processing Record 50 of Set 14 | magadan
# Processing Record 1 of Set 15 | george
# Processing Record 2 of Set 15 | goundam
# Processing Record 3 of Set 15 | hamilton
# Processing Record 4 of Set 15 | sobolevo
# Processing Record 5 of Set 15 | shenjiamen
# Processing Record 6 of Set 15 | pedernales
# Processing Record 7 of Set 15 | logansport
# Processing Record 8 of Set 15 | quelimane
# Processing Record 9 of Set 15 | nagato
# Processing Record 10 of Set 15 | yagodnoye
# Processing Record 11 of Set 15 | maniitsoq
# Processing Record 12 of Set 15 | rodos
# Processing Record 13 of Set 15 | parkes
# Processing Record 14 of Set 15 | kokkola
# Processing Record 15 of Set 15 | krasnyy chikoy
# Processing Record 16 of Set 15 | liverpool
# Processing Record 17 of Set 15 | lasa
# Processing Record 18 of Set 15 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 19 of Set 15 | karabulak
# Processing Record 20 of Set 15 | arman
# Processing Record 21 of Set 15 | white rock
# Processing Record 22 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 23 of Set 15 | faya
# Processing Record 24 of Set 15 | atasu
# Processing Record 25 of Set 15 | kattivakkam
# Processing Record 26 of Set 15 | yhu
# Processing Record 27 of Set 15 | semey
# Processing Record 28 of Set 15 | hongan
# City not found. Skipping...
# Processing Record 29 of Set 15 | svetlyy
# Processing Record 30 of Set 15 | soderhamn
# Processing Record 31 of Set 15 | kuna
# Processing Record 32 of Set 15 | imeni poliny osipenko
# Processing Record 33 of Set 15 | sarangani
# Processing Record 34 of Set 15 | corovode
# Processing Record 35 of Set 15 | belaya gora
# Processing Record 36 of Set 15 | sembe
# Processing Record 37 of Set 15 | fairlie
# Processing Record 38 of Set 15 | dali
# Processing Record 39 of Set 15 | porto novo
# Processing Record 40 of Set 15 | fukue
# Processing Record 41 of Set 15 | othonoi
# City not found. Skipping...
# Processing Record 42 of Set 15 | poso
# Processing Record 43 of Set 15 | tikapur
# Processing Record 44 of Set 15 | isangel
# Processing Record 45 of Set 15 | port arthur
# Processing Record 46 of Set 15 | lakes entrance
# Processing Record 47 of Set 15 | malindi
# Processing Record 48 of Set 15 | olafsvik
# Processing Record 49 of Set 15 | eyl
# Processing Record 50 of Set 15 | shirokiy
# Processing Record 1 of Set 16 | banda aceh
# Processing Record 2 of Set 16 | bensonville
# Processing Record 3 of Set 16 | korla
# Processing Record 4 of Set 16 | gangotri
# City not found. Skipping...
# Processing Record 5 of Set 16 | wagar
# Processing Record 6 of Set 16 | homer
# Processing Record 7 of Set 16 | rio gallegos
# Processing Record 8 of Set 16 | santiago de cao
# Processing Record 9 of Set 16 | sao miguel
# Processing Record 10 of Set 16 | linhares
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Ushuaia      AR -54.8000  -68.3000     42.46        93          75
# 1        Albany      US  42.6001  -73.9662     79.45        73           0
# 2    Moses Lake      US  47.1301 -119.2781     61.48        18           0
# 3        Pinhao      BR -25.6956  -51.6597     51.91        96           7
# 4  Puerto Ayora      EC  -0.7393  -90.3518     72.55        95         100
# 5     Pichayevo      RU  53.2363   42.2032     43.61        93          11
# 6         Altay      CN  47.8667   88.1167     61.79        29           7
# 7    Butaritari      KI   3.0707  172.7902     80.85        73          47
# 8       Rikitea      PF -23.1203 -134.9692     77.61        72           5
# 9       Samarai      PG -10.6167  150.6667     84.11        73          17
#
#    Wind Speed Current Description
# 0        8.05       broken clouds
# 1        5.01           clear sky
# 2        9.22           clear sky
# 3        3.18           clear sky
# 4        5.75     overcast clouds
# 5        7.58          few clouds
# 6        5.28           clear sky
# 7        8.03    scattered clouds
# 8       18.28           clear sky
# 9        5.19          few clouds

# %%
# Create the output file (CSV).
output_data_file = "Resources/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
